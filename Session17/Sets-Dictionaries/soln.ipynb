# %%
template = {
    'user_id': int,
    'name': {
        'first': str,
        'last': str
    },
    'bio': {
        'dob': {
            'year': int,
            'month': int,
            'day': int
        },
        'birthplace': {
            'country': str,
            'city': str
        }
    }
}

john = {
    'user_id': 100,
    'name': {
        'first': 'John',
        'last': 'Cleese'
    },
    'bio': {
        'dob': {
            'year': 1939,
            'month': 11,
            'day': 27
        },
        'birthplace': {
            'country': 'United Kingdom',
            'city': 'Weston-super-Mare'
        }
    }
}

# %%
for i in template:
    print(i)

temp
# Out:
# user_id
# name
# bio

# %%
template.keys() == john.keys()
# Out:
# True

# %%
    #   - For a missing key: `'mismatched keys: key_path'`
    #   - For a wrong data type: `'bad type: key_path'`

# %% [markdown]
# Declare two var dicts
# template, data
#
# type_map = {'int':int, 'str': str, 'dict':dict, 'tuple': tuple}
# final_keys =
#
# Recursively loop and check key equality in the key and the value
#
# def
#
# 1. Check if keys are equal if template.keys() == data.keys()
#
#
# def match_dict(template, data)
# for key in template.keys()
#     value_data = data.get(key)
#     value_template = template.get(key)
#     <!-- Check if key exists in the data -->
#     if value_data:
#         <!-- Check if the value is dict or str -->
#         <!-- Check if the type value_data and value_template is equal -->
#
#         if isinstance(value_data, dict) and isinstance(value_template, dict):
#             <!-- Recursively check if the two dicts matches -->
#
#             try:
#                 state, error  = match_dict(value_data, value_template)
#
#             except:
#                 pass
#
#         <!-- If value is str, then check input values for comparision -->
#         elif isinstance(value_template, str):
#             if isinstance(value_data, str) # type_map.get(value))
#         else: print('Type doesn't match')
#             if isinstance(value,type_map.get(value)):
#                 print('Keys are equal and type matches')
#
#     else:
#         raise 'mismatched keys: key'
#
#     for key1 in data.keys()
# if isinstance(template['key'], str)
#
# <!-- type detected -->
#
#
# type_map['']
#
# type = str
# 2. if keys are not equal, then then find the missing keys template.keys() -  data.keys() and return the missing keys raise keyerror(message)
# 3. for key in keys
# 4.

# %%
template = {
    'user_id': int,
    'name': {
        'first': str,
        'last': str
    },
    'bio': {
        'dob': {
            'year': int,
            'month': int,
            'day': int
        },
        'birthplace': {
            'country': str,
            'city': str
        }
    }
}

john = {
    'user_id': 100,
    'name': {
        'first': 'John',
        'last': 'Cleese'
    },
    'bio': {
        'dob': {
            'year': 1939,
            'month': 11,
            'day': 27
        },
        'birthplace': {
            'country': 'United Kingdom',
            'city': 'Weston-super-Mare'
        }
    }
}

# %%
def validate(data, template,  current_path=''):
    exception = ''
    key_path = ''
    state = True

    if len(data.keys()) > len(template.keys()):
        state = False
    
    for key in template.keys():
        key_path = f"{current_path}.{key}" if current_path else key
        print(f'\n\nNow checking the key - {key}')
        value_data = data.get(key)
        value_template = template.get(key)

        # print(type(value_template))

        print(value_data, value_template)
        #  Check if key exists in the data 
        if value_data:
            #  Check if the value is dict or str
            #  Check if the type value_data and value_template is equal
            #  value_data, value_template

            if isinstance(value_template, dict):
                # key_path = key_path + "." 
                
                if isinstance(value_data, dict):
                    # Recursively check if the two dicts matches
                    state, exception = validate(value_data, value_template, key_path)
                    if exception:
                        state = False
                        break
                else:
                    exception = f'mismatched keys: {key_path}'
                    state = False
                    break

            
            #  If value is str, then check input values for comparision -->
            else:
                print('In non dict type filter')
                print(value_data, value_template)
                if isinstance(value_data, value_template):
                    print("Type match")
                    # state = True
                    

                else: 
                    print('type mismatch')
                    exception =  f'bad type: {key_path}'
                    state = False
                    break
            

                    
        else:
            exception = f'mismatched keys: {key_path}'
            state = False
            break
    
    # # Loop for checking if the data doesn't have extra keys
    # for key in data.keys():
    #     key_path = f"{current_path}.{key}" if current_path else key
    #     print(f'\n\nNow checking the key - {key}')
    #     value_data = data.get(key)
    #     value_template = template.get(key)

    #     # print(type(value_template))

    #     print(value_data, value_template)
    #     #  Check if key exists in the data 
    #     if value_data:
    #         #  Check if the value is dict or str
    #         #  Check if the type value_data and value_template is equal
    #         #  value_data, value_template

    #         if isinstance(value_template, dict):
    #             # key_path = key_path + "." 
                
    #             if isinstance(value_data, dict):
    #                 # Recursively check if the two dicts matches
    #                 state, exception = validate(value_data, value_template, key_path)
    #                 if exception:
    #                     state = False
    #                     break
    #             else:
    #                 exception = f'mismatched keys: {key_path}'
    #                 state = False
    #                 break

            
    #         #  If value is str, then check input values for comparision -->
    #         else:
    #             print('In non dict type filter')
    #             print(value_data, value_template)
    #             if isinstance(value_data, value_template):
    #                 print("Type match")
    #                 # state = True
                    

    #             else: 
    #                 print('type mismatch')
    #                 exception =  f'bad type: {key_path}'
    #                 state = False
    #                 break
            

                    
    #     else:
    #         exception = f'mismatched keys: {key_path}'
    #         state = False
    #         break
    return state, exception

# %%
template = {
    'user_id': int,
    'name': {
        'first': str,
        'last': str
    },
    'bio': {
        'dob': {
            'year': int,
            'month': int,
            'day': int
        },
        'birthplace': {
            'country': str,
            'city': str
        }
    }
}

john = {
    'user_id': 100,
    'name': {
        'first': 'john',
        # 'last': 'Cleese'
    },
    'bio': {
        'dob': {
            'year': 1939,
            'month': 11,
            'day': 27
        },
        'birthplace': {
            'country': 'United Kingdom',
            'city': 'Weston-super-Mare'
        }
    }
}

# %%
op
# Out:
# (False, 'mismatched keys: name.last')

# %%
op = validate(template=template, data=john)
# Out:
# Now checking the key - user_id
# 100 <class 'int'>
# In non dict type filter
# 100 <class 'int'>
# Type match
#
#
# Now checking the key - name
# {'first': 'john'} {'first': <class 'str'>, 'last': <class 'str'>}
#
#
# Now checking the key - first
# john <class 'str'>
# In non dict type filter
# john <class 'str'>
# Type match
#
#
# Now checking the key - last
# None <class 'str'>

# %%
john = {
    'user_id': 100,
    'name': {
        'first': 'John',
        'last': 'Cleese'
    },
    'bio': {
        'dob': {
            'year': 1939,
            'month': 11,
            'day': 27
        },
        'birthplace': {
            'country': 'United Kingdom',
            'city': 'Weston-super-Mare'
        }
    }
}
state, error = validate(john, template)
assert state == True
assert error == ''
# Out:
# Now checking the key - user_id
# 100 <class 'int'>
# In non dict type filter
# 100 <class 'int'>
# Type match
#
#
# Now checking the key - name
# {'first': 'John', 'last': 'Cleese'} {'first': <class 'str'>, 'last': <class 'str'>}
#
#
# Now checking the key - first
# John <class 'str'>
# In non dict type filter
# John <class 'str'>
# Type match
#
#
# Now checking the key - last
# Cleese <class 'str'>
# In non dict type filter
# Cleese <class 'str'>
# Type match
#
#
# Now checking the key - bio
# {'dob': {'year': 1939, 'month': 11, 'day': 27}, 'birthplace': {'country': 'United Kingdom', 'city': 'Weston-super-Mare'}} {'dob': {'year': <class 'int'>, 'month': <class 'int'>, 'day': <class 'int'>}, 'birthplace': {'country': <class 'str'>, 'city': <class 'str'>}}
#
#
# Now checking the key - dob
# {'year': 1939, 'month': 11, 'day': 27} {'year': <class 'int'>, 'month': <class 'int'>, 'day': <class 'int'>}
#
#
# Now checking the key - year
# 1939 <class 'int'>
# In non dict type filter
# 1939 <class 'int'>
# Type match
#
#
# Now checking the key - month
# 11 <class 'int'>
# In non dict type filter
# 11 <class 'int'>
# Type match
#
#
# Now checking the key - day
# 27 <class 'int'>
# In non dict type filter
# 27 <class 'int'>
# Type match
#
#
# Now checking the key - birthplace
# {'country': 'United Kingdom', 'city': 'Weston-super-Mare'} {'country': <class 'str'>, 'city': <class 'str'>}
#
#
# Now checking the key - country
# United Kingdom <class 'str'>
# In non dict type filter
# United Kingdom <class 'str'>
# Type match
#
#
# Now checking the key - city
# Weston-super-Mare <class 'str'>
# In non dict type filter
# Weston-super-Mare <class 'str'>
# Type match
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[95], line 20
#       1 john = {
#       2     'user_id': 100,
#       3     'name': {
#    (...)
#      17     }
#      18 }
#      19 state, error = validate(john, template)
# ---> 20 assert state == False
#      21 assert error == ''
#
# AssertionError:
